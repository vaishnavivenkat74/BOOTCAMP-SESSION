# %%
weight = int(input("enter your weight:"))
unit = input("is your weight (K)g or in (L)bs")
if unit.upper() == "K":
    convertor = weight / 0.45
    print("your weight in pounds:"+ str(convertor))
else:
    convertor = weight*0.45
    print("your weight in kgs :"+ str(convertor))
# Out:
# enter your weight:58
# is your weight (K)g or in (L)bsk
# your weight in pounds:128.88888888888889

# %%
x =6
if x < 5:
    print("x is greater than 5")
    if x % 2 == 0:
        print("x is also even")
    else:
        print("x is odd")
else:
    print("x is 5 or less")
# Out:
# x is 5 or less

# %%
a = 200
b = 33
c = 250
if a > b and c > a:
    print("Both conditions are True")
else:
    print("condition not satisfied")
# Out:
# Both conditions are True

# %%
a = 200
b = 33
c = 130
if a < b or a < c:
    print("At least one of the conditions is True")
else:
    print("hi")
# Out:
# hi
